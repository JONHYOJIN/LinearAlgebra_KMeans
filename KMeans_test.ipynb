# %%
import pandas as pd
import numpy as np
from KMeans_getDF import KMeans_DF
from KMeans import Kmeans
from KMeans_graph import Kmeans_graph
from Cluster_represent import cluster_represent

kmeans_df = KMeans_DF()
data = kmeans_df.get_DF()

# %%
data
# Out:
#                Unfinished_portrait_of_Franklin_D._Roosevelt     Negan  \
# lead                                                    0.0  0.005114
# receive                                                 0.0  0.000000
# play                                                    0.0  0.001136
# american                                                0.0  0.000000
# release                                                 0.0  0.001705
# ...                                                     ...       ...
# philosophical                                           0.0  0.000000
# persian                                                 0.0  0.000000
# attendee                                                0.0  0.000000
# procession                                              0.0  0.000000
# cluster                                                 0.0  0.000000
#
#                Cam_Newton   Beyonce  Coachella_Valley_Music_and_Arts_Festival  \
# ...

# %%
KM = Kmeans(data, 10)
result_data, center_points, j_clusters = KM.do_kmeans()
graph = Kmeans_graph(result_data, center_points, j_clusters)
ngh = cluster_represent(result_data, center_points)

# %%
graph.j_cluster_plot()

# %%
graph.scatter_plot()

# %%
graph.pca_plot()

# %%
ngh.print_neighbor5()
# Out:
# 1th Cluster's Neighbors: ['Justin_Trudeau', 'Marco_Rubio', 'Jeremy_Corbyn', 'Malcolm_Turnbull', 'Philippine_presidential_election,_2016']
#
# 2th Cluster's Neighbors: ['Mahatma_Gandhi', 'Sigmund_Freud', 'Ben_Affleck', 'Carly_Fiorina', 'Frederick_Douglass']
#
# 3th Cluster's Neighbors: ['Leonardo_DiCaprio', 'Kate_Beckinsale', "Maureen_O'Hara", 'Star_Wars:_The_Force_Awakens', 'Star_Wars_Episode_I:_The_Phantom_Menace']
#
# 4th Cluster's Neighbors: ['Christopher_Paul_Neil']
#
# 5th Cluster's Neighbors: ['Wrestlemania_32', 'Andre_the_Giant', 'Ronda_Rousey', 'Floyd_Mayweather,_Jr.', 'Jose_Mourinho']
#
# 6th Cluster's Neighbors: ['Caroline_Herschel', 'Hertha_Marks_Ayrton']
#
# 7th Cluster's Neighbors: ['David_Bowie', 'Kanye_West', 'Charlie_Sheen', 'Celine_Dion', 'Ariana_Grande']
#
# 8th Cluster's Neighbors: ['Ash_Wednesday']
#
# 9th Cluster's Neighbors: ['2015_FIBA_Asia_Championship']
#
# 10th Cluster's Neighbors: ['Ben_Carson']
