# %%
import pandas as pd
import numpy as np
from KMeans_getDF import KMeans_DF

kmeans_df = KMeans_DF()
data = kmeans_df.get_DF()

# %%
data.head()
# Out:
#           Unfinished_portrait_of_Franklin_D._Roosevelt     Negan  Cam_Newton  \
# lead                                               0.0  0.005114    0.011914
# receive                                            0.0  0.000000    0.001862
# play                                               0.0  0.001136    0.008935
# american                                           0.0  0.000000    0.000745
# release                                            0.0  0.001705    0.000000
#
#            Beyonce  Coachella_Valley_Music_and_Arts_Festival  Charlie_Sheen  \
# lead      0.002739                                  0.002517       0.000937
# receive   0.005478                                  0.002517       0.003749
# play      0.002130                                  0.002517       0.003749
# american  0.004565                                  0.002517       0.001874
# release   0.011260                                  0.000000       0.001874
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4423 entries, lead to procession
# Columns: 500 entries, Unfinished_portrait_of_Franklin_D._Roosevelt to Carrie_Fisher
# dtypes: float64(500)
# memory usage: 16.9+ MB

# %%
data.describe()
# Out:
#        Unfinished_portrait_of_Franklin_D._Roosevelt        Negan   Cam_Newton  \
# count                                   4423.000000  4423.000000  4423.000000
# mean                                       0.000226     0.000226     0.000226
# std                                        0.002262     0.001436     0.002010
# min                                        0.000000     0.000000     0.000000
# 25%                                        0.000000     0.000000     0.000000
# 50%                                        0.000000     0.000000     0.000000
# 75%                                        0.000000     0.000000     0.000000
# max                                        0.083333     0.076136     0.075205
#
#            Beyonce  Coachella_Valley_Music_and_Arts_Festival  Charlie_Sheen  \
# count  4423.000000                               4423.000000    4423.000000
# mean      0.000226                                  0.000226       0.000226
# ...
